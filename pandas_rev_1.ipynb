# %%
import pandas as pd

# %%
#first we create dicti. to use or create data
dic={"name":["lucky","bhanu","shivam","mohan"],"age":[21,27,21,20],"salery":["50k","40k","30k","20k"]}

# %%
dic
# Out:
# {'name': ['lucky', 'bhanu', 'shivam', 'mohan'],
#  'age': [21, 27, 21, 20],
#  'salery': ['50k', '40k', '30k', '20k']}

# %%
df=pd.DataFrame(dic)
df
# Out:
#      name  age salery
# 0   lucky   21    50k
# 1   bhanu   27    40k
# 2  shivam   21    30k
# 3   mohan   20    20k

# %%
df["name"][0:4]
# Out:
# 0     lucky
# 1     bhanu
# 2    shivam
# 3     mohan
# Name: name, dtype: object

# %%
df["age"][0:]
# Out:
# 0    21
# 1    27
# 2    21
# 3    20
# Name: age, dtype: int64

# %%
#to create in csv file
df.to_csv("xyz.csv")

# %%
#1 methord to read any csv data 
df=pd.read_csv(r"C:/Users/hp/Desktop/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#2 methord to read any csv data 
df=pd.read_csv("C:\\Users\\hp\\Desktop\\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#3 methord to read any csv data 
df=pd.read_csv(r"C:/Users/hp/Desktop/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#to analysis a data we fatch data from csv file
df=pd.read_csv(r"C:\Users\hp\Desktop\Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.size
#13320*9
# Out:
# 119880

# %%
#to get the total or basic information about the file
df.info()
#where object represent catagorical data
#where float64 represent numerical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7819 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
#to get null value we use two function
#use one in the following
#isnull()==>we use this mainly
#notnull()

# %%
df.isnull()
#this function is use to denote null value
#when we need to findd the empty field
#if empty field than "true"
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False    False       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
#this function is use to denote null value
#when we need to find the empty field
#if empty field than "false"
df.notnull()
# Out:
#        area_type  availability  location  size  society  total_sqft  bath  \
# 0           True          True      True  True     True        True  True
# 1           True          True      True  True     True        True  True
# 2           True          True      True  True     True        True  True
# 3           True          True      True  True     True        True  True
# 4           True          True      True  True    False        True  True
# ...          ...           ...       ...   ...      ...         ...   ...
# 13315       True          True      True  True     True        True  True
# 13316       True          True      True  True    False        True  True
# 13317       True          True      True  True     True        True  True
# 13318       True          True      True  True     True        True  True
# 13319       True          True      True  True    False        True  True
#
#        balcony  price
# 0         True   True
# 1         True   True
# ...

# %%
#if we need to count number null value then we use sum
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5501
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#to observe data
