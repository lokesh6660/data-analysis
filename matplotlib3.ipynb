# %%
#histogram
#you define x axis only
#work on probability

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.random.normal(2,3,4)
x
# Out:
# array([ 1.73028577, -1.3682968 , -1.55898616,  1.30608669])

# %%
plt.hist(x)
# Out:
# (array([2., 0., 0., 0., 0., 0., 0., 0., 1., 1.]),
#  array([-1.55898616, -1.23005897, -0.90113178, -0.57220458, -0.24327739,
#          0.0856498 ,  0.41457699,  0.74350419,  1.07243138,  1.40135857,
#          1.73028577]),
#  <BarContainer object of 10 artists>)

# %%
y=[12,23,12,45,12,56,34,78,34]
plt.hist(y)
#it count how many time any number is occers
# Out:
# (array([3., 1., 0., 2., 0., 1., 1., 0., 0., 1.]),
#  array([12. , 18.6, 25.2, 31.8, 38.4, 45. , 51.6, 58.2, 64.8, 71.4, 78. ]),
#  <BarContainer object of 10 artists>)

# %%
#1 lavel 3D data plot
x=[12,32,13,34,46,23,43]
y=[32,54,33,44,23,54,33]
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
#2 lavel 3D data plot
x=[12,32,13,34,46,23,43]
y=[32,54,33,44,23,54,33]
plt.subplot(2,2,1)
plt.plot(x,y)
