# %%
import pandas as pd

# %%
#wap to find the house having more than 2 bathroom
df=pd.read_csv(r"C:\Users\hp\Desktop\Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#wap to find the house having more than 2 bathroom
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df["society"].fillna("GrrvaGr",inplace=True)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df["bath"]>2
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 13315     True
# 13316     True
# 13317    False
# 13318     True
# 13319    False
# Name: bath, Length: 13320, dtype: bool

# %%
df[df["bath"]>2]["location"]
# Out:
# 1          Chikka Tirupathi
# 3        Lingadheeranahalli
# 6          Old Airport Road
# 7              Rajaji Nagar
# 8              Marathahalli
#                 ...
# 13311      Ramamurthy Nagar
# 13314     Green Glen Layout
# 13315            Whitefield
# 13316         Richards Town
# 13318       Padmanabhanagar
# Name: location, Length: 5551, dtype: object

# %%
#to find society also in the data ans so on.
df[df["bath"]>2][["location","society"]]
# Out:
#                  location  society
# 1        Chikka Tirupathi  Theanmp
# 3      Lingadheeranahalli  Soiewre
# 6        Old Airport Road  Jaades
# 7            Rajaji Nagar  Brway G
# 8            Marathahalli  GrrvaGr
# ...                   ...      ...
# 13311    Ramamurthy Nagar  GrrvaGr
# 13314   Green Glen Layout  SoosePr
# 13315          Whitefield  ArsiaEx
# 13316       Richards Town  GrrvaGr
# 13318     Padmanabhanagar  SollyCl
#
# [5551 rows x 2 columns]

# %%
# to get location and society of those which having more than 10 bath 
df[df["bath"]>10][["location","society"]]
# Out:
#                             location  society
# 938               5th Phase JP Nagar  GrrvaGr
# 1078                   BTM 1st Stage  Srvasks
# 1718       2Electronic City Phase II  GrrvaGr
# 1768              1 Ramamurthy Nagar  GrrvaGr
# 1953                        KR Puram  GrrvaGr
# 1979                     Hongasandra  GrrvaGr
# 3096            Jp nagar 8th Phase .  GrrvaGr
# 3379                  1Hanuman Nagar  GrrvaGr
# 3609   Koramangala Industrial Layout  GrrvaGr
# 4684                     Munnekollal  GrrvaGr
# 4916                   1Channasandra  GrrvaGr
# 6937            5th Block Hbr Layout  GrrvaGr
# 7979                   1 Immadihalli  GrrvaGr
# 8106                   Wilson Garden  GrrvaGr
# 8636                  Neeladri Nagar  GrrvaGr
# 9935                   1Hoysalanagar  GrrvaGr
# 10695                Electronic City  GrrvaGr
# 11128                         Jigani  GrrvaGr
# 11559                  1Kasavanhalli  HMwerCo
# ...

# %%
#this is rendome value fill
df.fillna(0)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#if we want to comit change in the data and save in the new variable
df1=df.fillna(0)
df1
# we do not use "inplace()" because it autometical save
#we use inplace when we conver cat. data in tu num. data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#we also use inplace with main data frame
df.fillna(0,inplace=True)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
