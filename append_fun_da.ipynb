# %%
import pandas as pd
#groupby 
#merge
#append
#concate
#join

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\IPL Matches 2008-2020.csv")
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c.append(7)
c
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
df["city"].append(pd.Series("XYZ"))
#here we need to create series type data to append  xyz
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2788\1282951080.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df["city"].append(pd.Series("XYZ"))
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# 0             XYZ
# Length: 817, dtype: object

# %%
#if we want to append data in multipal columns than we need to create data frame
#of city and venue than we need to create a data frame of new data to append to 
#another data frame of city and venue
df[["city","venue"]].append(pd.DataFrame(["xyz"]))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2788\3955178131.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df[["city","venue"]].append(pd.DataFrame(["xyz"]))
#            city                                       venue    0
# 0     Bangalore                       M Chinnaswamy Stadium  NaN
# 1    Chandigarh  Punjab Cricket Association Stadium, Mohali  NaN
# 2         Delhi                            Feroz Shah Kotla  NaN
# 3        Mumbai                            Wankhede Stadium  NaN
# 4       Kolkata                                Eden Gardens  NaN
# ..          ...                                         ...  ...
# 812       Dubai         Dubai International Cricket Stadium  NaN
# 813   Abu Dhabi                        Sheikh Zayed Stadium  NaN
# 814   Abu Dhabi                        Sheikh Zayed Stadium  NaN
# 815       Dubai         Dubai International Cricket Stadium  NaN
# ...
